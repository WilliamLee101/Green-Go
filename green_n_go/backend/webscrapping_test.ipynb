# %%
import requests
from datetime import date

meals_time = ["breakfast", "lunch", "dinner"]
today = date.today()
print(today)

URLs = {"marciano": "https://www.bu.edu/dining/location/marciano/#menu", "warren": "https://www.bu.edu/dining/location/warren/#menu", "west":"https://www.bu.edu/dining/location/west/#menu"}
dining_halls = ["marciano", "warren", "west"]
updated_menu = {}
updated_menu[str(today)] = {}

# print(page.text)
# Out:
# 2023-03-12

# %%
import requests
from datetime import date

meals_time = ["breakfast", "lunch", "dinner"]
today = date.today()
URLs = {"marciano": "https://www.bu.edu/dining/location/marciano/#menu", "warren": "https://www.bu.edu/dining/location/warren/#menu", "west":"https://www.bu.edu/dining/location/west/#menu"}


# print(page.text)
from bs4 import BeautifulSoup
updated_menu = {}
updated_menu[str(today)] = {}
details = ["cals", "saturated fat", "carbs", "sugars", "proteins"]

for dining_hall in URLs.keys():
    URL = URLs[dining_hall]
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    updated_menu[str(today)][dining_hall] = {}
    
    for meal_time in meals_time:
        id = str(today)+"-"+meal_time
        updated_menu[str(today)][dining_hall][meal_time] = {}
        results = soup.find(id=id)
        xs = results.find_all("li", class_="menu-item menu-main menu-has-warning")
        for x in xs:
            title = x.find("h4", class_="js-nutrition-open-alias menu-item-title").text
            updated_menu[str(today)][dining_hall][meal_time][title] = {}
            updated_menu[str(today)][dining_hall][meal_time][title]["item"] = title
            descripton = x.find("p", class_="menu-description")
            if descripton != None:
                descripton = descripton.text
                descripton = descripton.replace("\t\t\t\t", "")
                descripton = descripton.replace("\n\t\t\t\t\t", "")
                descripton = descripton.replace("\n\t", "")
                updated_menu[str(today)][dining_hall][meal_time][title]["description"] = descripton
            z = x.find("ul", class_="menu-nutrition-overview")
            if not z==None:
                for line in z:
                    line = line.text
                    for detail in details:
                        if detail in line:
                            updated_menu[str(today)][dining_hall][meal_time][title][detail]=line

# %%
updated_menu
# Out:
# {'2023-03-13': {'marciano': {'breakfast': {'Old Fashioned Oatmeal': {'item': 'Old Fashioned Oatmeal',
#      'description': 'Homestyle oatmeal cereal',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Raisins': {'item': 'Raisins',
#      'description': 'Seedless raisins',
#      'cals': '135 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '32g carbs',
#      'sugars': '30g sugars',
#      'proteins': '1g proteins'},
#     'Brown Sugar': {'item': 'Brown Sugar',
#      'description': 'Light brown sugar',
#      'cals': '55 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '14g carbs',
#      'sugars': '14g sugars',
#      'proteins': '0g proteins'},
#     'Dried Fruit Mix': {'item': 'Dried Fruit Mix',
#      'description': 'Dried Fruit Medley of Dark Raisins, Natural Diced Apricot, Cranberries, Toasted Coconut,',
#      'cals': '70 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '13g sugars',
#      'proteins': '1g proteins'},
#     'Blueberry Muffin': {'item': 'Blueberry Muffin',
#      'cals': '155 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '21g carbs',
#      'sugars': '9g sugars',
#      'proteins': '2g proteins'},
#     'Berry Compote': {'item': 'Berry Compote',
#      'cals': '300 cals',
#      'saturated fat': '7g saturated fat',
#      'carbs': '50g carbs',
#      'sugars': '41g sugars',
#      'proteins': '1g proteins'},
#     'Banana Bread with Caramel Cream and Mango Salsa': {'item': 'Banana Bread with Caramel Cream and Mango Salsa',
#      'cals': '435 cals',
#      'saturated fat': '8g saturated fat',
#      'carbs': '73g carbs',
#      'sugars': '48g sugars',
#      'proteins': '5g proteins'},
#     'Scrambled Eggs': {'item': 'Scrambled Eggs',
#      'description': 'Cage Free egs scrambled with salt and pepper',
#      'cals': '185 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '16g proteins'},
#     'Turkey Sausage': {'item': 'Turkey Sausage',
#      'description': 'Golden brown savory turkey sausage link',
#      'cals': '90 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '10g proteins'},
#     'French Toast': {'item': 'French Toast',
#      'description': 'Golden brown and fluffy cinnamon-spiced thick-cut French toast',
#      'cals': '365 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '48g carbs',
#      'sugars': '16g sugars',
#      'proteins': '16g proteins'},
#     "O'Brien Potatoes": {'item': "O'Brien Potatoes",
#      'description': 'Pan-fried seasoned diced potatoes and sauteed green and red peppers and onions',
#      'cals': '135 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '1g sugars',
#      'proteins': '2g proteins'},
#     'Tofu Scramble': {'item': 'Tofu Scramble',
#      'cals': '185 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '8g carbs',
#      'sugars': '0g sugars',
#      'proteins': '11g proteins'},
#     'Creole Sauce': {'item': 'Creole Sauce'},
#     'Create Your Own Omelet Station': {'item': 'Create Your Own Omelet Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Egg & Cheese Bagel': {'item': 'Egg & Cheese Bagel',
#      'description': 'Fried egg and American cheese on a bagel',
#      'cals': '445 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '44g carbs',
#      'sugars': '5g sugars',
#      'proteins': '17g proteins'},
#     'Turkey Bacon': {'item': 'Turkey Bacon',
#      'description': 'Crispy turkey bacon strip',
#      'cals': '60 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '4g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'}},
#    'lunch': {'Vegan Chocolate Brownie': {'item': 'Vegan Chocolate Brownie',
#      'cals': '325 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '57g carbs',
#      'sugars': '32g sugars',
#      'proteins': '5g proteins'},
#     'Lemon Bar': {'item': 'Lemon Bar',
#      'description': 'Lemony-sweet dessert bar with a delicate shortbread crust',
#      'cals': '350 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '63g carbs',
#      'sugars': '43g sugars',
#      'proteins': '2g proteins'},
#     'M&M Fudge Brownie': {'item': 'M&M Fudge Brownie',
#      'cals': '255 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '31g sugars',
#      'proteins': '3g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'description': 'Mozzarella, Asiago and pizza sauce',
#      'cals': '265 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '3g sugars',
#      'proteins': '10g proteins'},
#     'White Pizza': {'item': 'White Pizza',
#      'cals': '345 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '2g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Cheese Pizza': {'item': 'Vegan Cheese Pizza',
#      'description': 'Vegan mozzarella and tomato sauce on hand stretched crust',
#      'cals': '240 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '4g sugars',
#      'proteins': '7g proteins'},
#     'Chicken Parmesan Sub': {'item': 'Chicken Parmesan Sub',
#      'description': 'Breaded Fried Chicken Breast, Marinara, and Mozzarella On A Sub Roll',
#      'cals': '720 cals',
#      'saturated fat': '9g saturated fat',
#      'carbs': '71g carbs',
#      'sugars': '6g sugars',
#      'proteins': '55g proteins'},
#     'Ranch Potato Chips': {'item': 'Ranch Potato Chips',
#      'description': 'Crispy house-made potato chips seasoned with a ranch spice blend',
#      'cals': '100 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Fresh Homemade Pasta': {'item': 'Fresh Homemade Pasta',
#      'cals': '100 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Creole Sauce': {'item': 'Creole Sauce'},
#     'Sweet & Sour Pork': {'item': 'Sweet & Sour Pork',
#      'cals': '165 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '14g sugars',
#      'proteins': '11g proteins'},
#     'White Rice': {'item': 'White Rice',
#      'description': 'Slow-simmered long grain white rice',
#      'cals': '120 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '26g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup',
#      'description': 'Rich homemade tomato soup with cream and fresh basil',
#      'cals': '205 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '12g sugars',
#      'proteins': '5g proteins'},
#     'Crema': {'item': 'Crema',
#      'cals': '20 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Pepperoni Pizza': {'item': 'Pepperoni Pizza',
#      'description': 'Pepperoni, mozzarella and pizza sauce',
#      'cals': '275 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '35g carbs',
#      'sugars': '4g sugars',
#      'proteins': '11g proteins'},
#     'Apple, Parsnip & Leek Soup': {'item': 'Apple, Parsnip & Leek Soup',
#      'cals': '160 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '28g carbs',
#      'sugars': '11g sugars',
#      'proteins': '2g proteins'},
#     'Warm Cinnamon Quinoa': {'item': 'Warm Cinnamon Quinoa',
#      'cals': '100 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '4g sugars',
#      'proteins': '4g proteins'},
#     'Cauliflower Crust Primavera Pizza': {'item': 'Cauliflower Crust Primavera Pizza'},
#     'Chashu Pulled Pork': {'item': 'Chashu Pulled Pork'},
#     'Corn': {'item': 'Corn'},
#     'Steamed Spinach': {'item': 'Steamed Spinach'},
#     'Sliced Red Bell Peppers': {'item': 'Sliced Red Bell Peppers'},
#     'Vegan Chicken Udon Noodle Bowl': {'item': 'Vegan Chicken Udon Noodle Bowl',
#      'description': 'Veggie stir fry with meatless chicken strips, pasta and chili garlic sauce.',
#      'cals': '170 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '28g carbs',
#      'sugars': '6g sugars',
#      'proteins': '9g proteins'},
#     'Curried Tomato Lentil Soup': {'item': 'Curried Tomato Lentil Soup',
#      'description': 'Lentils, tomatoes, onion, carrot and celery simmered in herbed broth seasoned with garam masala',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '21g carbs',
#      'sugars': '3g sugars',
#      'proteins': '6g proteins'},
#     'Mango Quinoa Salad': {'item': 'Mango Quinoa Salad',
#      'description': 'Quinoa, mango, cranberries, jalapeno and green onions on a bed of greens topped with toasted almonds',
#      'cals': '350 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '32g carbs',
#      'sugars': '15g sugars',
#      'proteins': '6g proteins'},
#     'Watermelon Cubes': {'item': 'Watermelon Cubes'}},
#    'dinner': {'Vegan Vanilla Spice Cupcake': {'item': 'Vegan Vanilla Spice Cupcake',
#      'cals': '315 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '33g sugars',
#      'proteins': '2g proteins'},
#     'Cherry Cobbler': {'item': 'Cherry Cobbler',
#      'description': 'Warm juicy sweet cherries with a crunchy oatmeal biscuit crust',
#      'cals': '200 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '39g carbs',
#      'sugars': '24g sugars',
#      'proteins': '2g proteins'},
#     'Pumpkin Pastie': {'item': 'Pumpkin Pastie',
#      'cals': '530 cals',
#      'saturated fat': '21g saturated fat',
#      'carbs': '56g carbs',
#      'sugars': '19g sugars',
#      'proteins': '6g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'cals': '245 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '4g sugars',
#      'proteins': '15g proteins'},
#     'White Pizza': {'item': 'White Pizza',
#      'cals': '345 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '2g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Cheese Pizza': {'item': 'Vegan Cheese Pizza',
#      'description': 'Vegan mozzarella and tomato sauce on hand stretched crust',
#      'cals': '240 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '4g sugars',
#      'proteins': '7g proteins'},
#     'Korean Mushroom Sandwich': {'item': 'Korean Mushroom Sandwich',
#      'description': 'Portobello mushrooms with a fried egg & scallions topped with Gochujang sauce on a Kaiser roll',
#      'cals': '365 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '45g carbs',
#      'sugars': '13g sugars',
#      'proteins': '15g proteins'},
#     'Ranch Potato Chips': {'item': 'Ranch Potato Chips',
#      'description': 'Crispy house-made potato chips seasoned with a ranch spice blend',
#      'cals': '100 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Garlic Oregano Baguette': {'item': 'Garlic Oregano Baguette',
#      'description': 'Warm crusty baguette brushed with garlic-oregano oil',
#      'cals': '375 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Create Your Own Pasta Station': {'item': 'Create Your Own Pasta Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Naan Bread': {'item': 'Naan Bread',
#      'description': 'Freshly grilled Indian flatbread seasoned with toasted garam masala',
#      'cals': '215 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '35g carbs',
#      'sugars': '2g sugars',
#      'proteins': '6g proteins'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup',
#      'description': 'Rich homemade tomato soup with cream and fresh basil',
#      'cals': '205 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '12g sugars',
#      'proteins': '5g proteins'},
#     'Crema': {'item': 'Crema',
#      'cals': '20 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Cajun Roasted Pork Loin': {'item': 'Cajun Roasted Pork Loin',
#      'description': 'Slow roasted Cajun-seasoned pork loin',
#      'cals': '300 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '0g sugars',
#      'proteins': '26g proteins'},
#     'Apple, Parsnip & Leek Soup': {'item': 'Apple, Parsnip & Leek Soup',
#      'cals': '160 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '28g carbs',
#      'sugars': '11g sugars',
#      'proteins': '2g proteins'},
#     'Warm Cinnamon Quinoa': {'item': 'Warm Cinnamon Quinoa',
#      'cals': '100 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '4g sugars',
#      'proteins': '4g proteins'},
#     'White Rice': {'item': 'White Rice',
#      'description': 'Slow-simmered long grain white rice',
#      'cals': '120 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '26g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Lo Mein Noodles': {'item': 'Lo Mein Noodles',
#      'description': 'Steamed lo mein noodles',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '23g carbs',
#      'sugars': '0g sugars',
#      'proteins': '4g proteins'},
#     'Bok Choy': {'item': 'Bok Choy'},
#     'Sliced Red Bell Peppers': {'item': 'Sliced Red Bell Peppers'},
#     'Edamame': {'item': 'Edamame'},
#     'Udon Noodles': {'item': 'Udon Noodles'},
#     'Vegan Biriyani': {'item': 'Vegan Biriyani',
#      'description': 'Sauteed curry-spiced chicken, basmati rice and crispy onions baked with Indian-spiced yogurt sauce',
#      'cals': '250 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '49g carbs',
#      'sugars': '10g sugars',
#      'proteins': '6g proteins'},
#     'Curried Tomato Lentil Soup': {'item': 'Curried Tomato Lentil Soup',
#      'description': 'Lentils, tomatoes, onion, carrot and celery simmered in herbed broth seasoned with garam masala',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '21g carbs',
#      'sugars': '3g sugars',
#      'proteins': '6g proteins'},
#     'Create Your Own Vegan Station': {'item': 'Create Your Own Vegan Station',
#      'description': 'Create Your Own Vegan Entrée',
#      'cals': '830 cals',
#      'saturated fat': '8g saturated fat',
#      'carbs': '137g carbs',
#      'sugars': '20g sugars',
#      'proteins': '31g proteins'},
#     'Hummus with Veggie': {'item': 'Hummus with Veggie',
#      'description': 'Creamy hummus with celery, carrot and cucumber dippers',
#      'cals': '120 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '3g sugars',
#      'proteins': '4g proteins'},
#     'Create Your Own Sandwich Station': {'item': 'Create Your Own Sandwich Station',
#      'description': 'Create Your Own Sandwich Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'}}},
#   'warren': {'breakfast': {'Scrambled Eggs': {'item': 'Scrambled Eggs',
#      'description': 'Cage Free egs scrambled with salt and pepper',
#      'cals': '185 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '16g proteins'},
#     'Turkey Sausage Patty': {'item': 'Turkey Sausage Patty',
#      'description': 'Sizzling hot golden brown turkey sausage patty',
#      'cals': '90 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Whole Wheat French Toast': {'item': 'Whole Wheat French Toast',
#      'cals': '280 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '40g carbs',
#      'sugars': '9g sugars',
#      'proteins': '20g proteins'},
#     'Chocolate Chip Pancakes': {'item': 'Chocolate Chip Pancakes',
#      'description': 'Homemade pancakes filled with sweet chocolate bits',
#      'cals': '295 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '45g carbs',
#      'sugars': '19g sugars',
#      'proteins': '6g proteins'},
#     'Hard Boiled Egg': {'item': 'Hard Boiled Egg',
#      'description': 'Peeled hard-cooked egg',
#      'cals': '70 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '1g sugars',
#      'proteins': '6g proteins'},
#     'Santa Fe Potatoes': {'item': 'Santa Fe Potatoes',
#      'description': 'Pan-fried diced red potatoes, red peppers and onions seasoned with a Southwest spice blend',
#      'cals': '200 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '28g carbs',
#      'sugars': '3g sugars',
#      'proteins': '3g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Pineapple-Banana Smoothie': {'item': 'Pineapple-Banana Smoothie',
#      'cals': '105 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '26g carbs',
#      'sugars': '17g sugars',
#      'proteins': '2g proteins'},
#     'Tofu Scramble': {'item': 'Tofu Scramble',
#      'cals': '185 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '8g carbs',
#      'sugars': '0g sugars',
#      'proteins': '11g proteins'},
#     'Create Your Own Omelet Station': {'item': 'Create Your Own Omelet Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Old Fashioned Oatmeal': {'item': 'Old Fashioned Oatmeal',
#      'description': 'Homestyle oatmeal cereal',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Raisins': {'item': 'Raisins',
#      'description': 'Seedless raisins',
#      'cals': '135 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '32g carbs',
#      'sugars': '30g sugars',
#      'proteins': '1g proteins'},
#     'Dried Fruit Mix': {'item': 'Dried Fruit Mix',
#      'description': 'Dried Fruit Medley of Dark Raisins, Natural Diced Apricot, Cranberries, Toasted Coconut,',
#      'cals': '70 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '13g sugars',
#      'proteins': '1g proteins'},
#     'Brown Sugar': {'item': 'Brown Sugar',
#      'description': 'Light brown sugar',
#      'cals': '55 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '14g carbs',
#      'sugars': '14g sugars',
#      'proteins': '0g proteins'},
#     'Carrot Raisin Muffin': {'item': 'Carrot Raisin Muffin',
#      'cals': '275 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '37g carbs',
#      'sugars': '18g sugars',
#      'proteins': '4g proteins'},
#     'Turkey Sausage': {'item': 'Turkey Sausage',
#      'description': 'Golden brown savory turkey sausage link',
#      'cals': '90 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '10g proteins'}},
#    'lunch': {'Grilled Turkey Rachel': {'item': 'Grilled Turkey Rachel',
#      'description': 'Sliced turkey breast, Swiss cheese, sauerkraut and Thousand Island dressing on marble rye bread',
#      'cals': '545 cals',
#      'saturated fat': '10g saturated fat',
#      'carbs': '48g carbs',
#      'sugars': '1g sugars',
#      'proteins': '25g proteins'},
#     'Ranch Potato Chips': {'item': 'Ranch Potato Chips',
#      'description': 'Crispy house-made potato chips seasoned with a ranch spice blend',
#      'cals': '100 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'cals': '245 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '4g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Cheese Pizza': {'item': 'Vegan Cheese Pizza',
#      'description': 'Vegan mozzarella and tomato sauce on hand stretched crust',
#      'cals': '240 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '4g sugars',
#      'proteins': '7g proteins'},
#     'Buffalo Chicken Pizza': {'item': 'Buffalo Chicken Pizza',
#      'description': 'Grilled chicken, Buffalo wing sauce, mozzarella and blue cheese',
#      'cals': '425 cals',
#      'saturated fat': '8g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '3g sugars',
#      'proteins': '27g proteins'},
#     'Eggplant Lasagna': {'item': 'Eggplant Lasagna',
#      'cals': '255 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '35g carbs',
#      'sugars': '11g sugars',
#      'proteins': '12g proteins'},
#     'Smokey Pineapple Hot Sauce': {'item': 'Smokey Pineapple Hot Sauce',
#      'description': 'Char-grilled pineapples & jalapeño blended with chipotle and a citrus blend .',
#      'cals': '10 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '2g sugars',
#      'proteins': '0g proteins'},
#     'Fire Roasted Pepper Sauce': {'item': 'Fire Roasted Pepper Sauce',
#      'description': 'Fire Roasted Red Peppers blended with dried ancho and habanero',
#      'cals': '20 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Queso Fresco': {'item': 'Queso Fresco',
#      'description': 'Crumbled queso fresco',
#      'cals': '405 cals',
#      'saturated fat': '20g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '4g sugars',
#      'proteins': '24g proteins'},
#     'Mango-Lemon Agua Fresca': {'item': 'Mango-Lemon Agua Fresca',
#      'description': 'Fresh mango mixed with lemon juice & agave',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '30g carbs',
#      'sugars': '24g sugars',
#      'proteins': '0g proteins'},
#     'Crema': {'item': 'Crema',
#      'cals': '20 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Salsa Roja': {'item': 'Salsa Roja'},
#     'Create Your Own': {'item': 'Create Your Own',
#      'cals': '405 cals',
#      'saturated fat': '20g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '4g sugars',
#      'proteins': '24g proteins'},
#     'Diced Beef': {'item': 'Diced Beef',
#      'cals': '150 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '24g proteins'},
#     'Create Your Own Stir Fry': {'item': 'Create Your Own Stir Fry',
#      'description': 'Broccoli, spinach, chickpeas, olives and banana peppers sauteed with spaghetti sauce over brown rice',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Blue Cheese Dressing': {'item': 'Blue Cheese Dressing'},
#     'Create Your Own Salad Bar': {'item': 'Create Your Own Salad Bar',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Cannoli Tart': {'item': 'Cannoli Tart',
#      'cals': '275 cals',
#      'saturated fat': '7g saturated fat',
#      'carbs': '33g carbs',
#      'sugars': '19g sugars',
#      'proteins': '7g proteins'},
#     'Banana Cake': {'item': 'Banana Cake',
#      'cals': '275 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '24g sugars',
#      'proteins': '3g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Roast Beef Sandwich with Blue Cheese': {'item': 'Roast Beef Sandwich with Blue Cheese',
#      'cals': '295 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '39g carbs',
#      'sugars': '8g sugars',
#      'proteins': '21g proteins'},
#     'Roasted Shawarma Chickpeas': {'item': 'Roasted Shawarma Chickpeas',
#      'cals': '115 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '3g sugars',
#      'proteins': '6g proteins'},
#     'Trail Mix': {'item': 'Trail Mix',
#      'description': 'Crunchy low fat granola',
#      'cals': '215 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '18g sugars',
#      'proteins': '3g proteins'},
#     'Hummus with Veggie': {'item': 'Hummus with Veggie',
#      'description': 'Creamy hummus with celery, carrot and cucumber dippers',
#      'cals': '120 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '3g sugars',
#      'proteins': '4g proteins'},
#     'Apple Slices With Sunbutter': {'item': 'Apple Slices With Sunbutter',
#      'description': 'Fresh Local Apple Slices with Sunflower Seed Butter',
#      'cals': '570 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '25g carbs',
#      'sugars': '17g sugars',
#      'proteins': '7g proteins'},
#     'Create Your Own Sandwich Station': {'item': 'Create Your Own Sandwich Station',
#      'description': 'Create Your Own Sandwich Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup',
#      'description': 'Rich homemade tomato soup with cream and fresh basil',
#      'cals': '205 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '12g sugars',
#      'proteins': '5g proteins'},
#     'Turkey & Brown Rice Soup': {'item': 'Turkey & Brown Rice Soup',
#      'cals': '75 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '2g sugars',
#      'proteins': '5g proteins'},
#     'Jerk Grilled Salmon': {'item': 'Jerk Grilled Salmon',
#      'description': 'Grilled Filet of Salmon with hints of allspice, cinnamon and chilis',
#      'cals': '135 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '17g proteins'},
#     'Chocolate Chip Blondie': {'item': 'Chocolate Chip Blondie',
#      'cals': '260 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '27g sugars',
#      'proteins': '2g proteins'},
#     'Confetti Brown Rice': {'item': 'Confetti Brown Rice',
#      'description': 'Seasoned brown rice with diced onion and bell peppers',
#      'cals': '125 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '22g carbs',
#      'sugars': '1g sugars',
#      'proteins': '2g proteins'},
#     'Lentil Soup': {'item': 'Lentil Soup',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '3g sugars',
#      'proteins': '5g proteins'},
#     'Steamed Green Beans': {'item': 'Steamed Green Beans',
#      'description': 'Steamed fresh whole green beans',
#      'cals': '30 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '6g carbs',
#      'sugars': '3g sugars',
#      'proteins': '2g proteins'},
#     'Sunflower Chicken': {'item': 'Sunflower Chicken',
#      'description': 'Stir-fried chicken, sunflower seed, water chestnuts, celery and green onions in flavorful Asian sauce',
#      'cals': '200 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '16g carbs',
#      'sugars': '3g sugars',
#      'proteins': '11g proteins'}},
#    'dinner': {'Avocado Ranch Crispy Chicken Sandwich': {'item': 'Avocado Ranch Crispy Chicken Sandwich',
#      'description': 'Chicken patty with lettuce, tomato and avocado ranch',
#      'cals': '470 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '3g sugars',
#      'proteins': '19g proteins'},
#     'Ranch Potato Chips': {'item': 'Ranch Potato Chips',
#      'description': 'Crispy house-made potato chips seasoned with a ranch spice blend',
#      'cals': '100 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'cals': '245 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '4g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Cheese Pizza': {'item': 'Vegan Cheese Pizza',
#      'description': 'Vegan mozzarella and tomato sauce on hand stretched crust',
#      'cals': '240 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '4g sugars',
#      'proteins': '7g proteins'},
#     'Buffalo Chicken Pizza': {'item': 'Buffalo Chicken Pizza',
#      'description': 'Grilled chicken, Buffalo wing sauce, mozzarella and blue cheese',
#      'cals': '425 cals',
#      'saturated fat': '8g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '3g sugars',
#      'proteins': '27g proteins'},
#     'Vegan Meat Stew': {'item': 'Vegan Meat Stew',
#      'description': 'Hearty tomato sauce with peppers, onion, garlic and meatless beef crumbles',
#      'cals': '160 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '16g carbs',
#      'sugars': '2g sugars',
#      'proteins': '13g proteins'},
#     'Yellow Rice with Raisins from South Africa': {'item': 'Yellow Rice with Raisins from South Africa',
#      'cals': '145 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '31g carbs',
#      'sugars': '7g sugars',
#      'proteins': '2g proteins'},
#     'Queso Fresco': {'item': 'Queso Fresco',
#      'description': 'Crumbled queso fresco',
#      'cals': '405 cals',
#      'saturated fat': '20g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '4g sugars',
#      'proteins': '24g proteins'},
#     'Mango-Lemon Agua Fresca': {'item': 'Mango-Lemon Agua Fresca',
#      'description': 'Fresh mango mixed with lemon juice & agave',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '30g carbs',
#      'sugars': '24g sugars',
#      'proteins': '0g proteins'},
#     'Fire Roasted Pepper Sauce': {'item': 'Fire Roasted Pepper Sauce',
#      'description': 'Fire Roasted Red Peppers blended with dried ancho and habanero',
#      'cals': '20 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Smokey Pineapple Hot Sauce': {'item': 'Smokey Pineapple Hot Sauce',
#      'description': 'Char-grilled pineapples & jalapeño blended with chipotle and a citrus blend .',
#      'cals': '10 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '2g sugars',
#      'proteins': '0g proteins'},
#     'Crema': {'item': 'Crema',
#      'cals': '20 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Salsa Roja': {'item': 'Salsa Roja'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Sweet and Sour Tofu': {'item': 'Sweet and Sour Tofu',
#      'cals': '250 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '31g carbs',
#      'sugars': '19g sugars',
#      'proteins': '10g proteins'},
#     'Brown Rice': {'item': 'Brown Rice',
#      'description': 'Tender cooked brown rice',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '23g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Blue Cheese Dressing': {'item': 'Blue Cheese Dressing'},
#     'Create Your Own Salad Bar': {'item': 'Create Your Own Salad Bar',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Pineapple Upside Down Cake': {'item': 'Pineapple Upside Down Cake',
#      'description': 'Freshly baked yellow cake with a rich brown sugar and pineapple topping',
#      'cals': '155 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '29g carbs',
#      'sugars': '20g sugars',
#      'proteins': '1g proteins'},
#     'Vegan Apple Crisp': {'item': 'Vegan Apple Crisp',
#      'cals': '280 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '57g carbs',
#      'sugars': '42g sugars',
#      'proteins': '2g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Roast Beef Sandwich with Blue Cheese': {'item': 'Roast Beef Sandwich with Blue Cheese',
#      'cals': '295 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '39g carbs',
#      'sugars': '8g sugars',
#      'proteins': '21g proteins'},
#     'Roasted Shawarma Chickpeas': {'item': 'Roasted Shawarma Chickpeas',
#      'cals': '115 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '3g sugars',
#      'proteins': '6g proteins'},
#     'Trail Mix': {'item': 'Trail Mix',
#      'description': 'Crunchy low fat granola',
#      'cals': '215 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '18g sugars',
#      'proteins': '3g proteins'},
#     'Hummus with Veggie': {'item': 'Hummus with Veggie',
#      'description': 'Creamy hummus with celery, carrot and cucumber dippers',
#      'cals': '120 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '3g sugars',
#      'proteins': '4g proteins'},
#     'Apple Slices With Sunbutter': {'item': 'Apple Slices With Sunbutter',
#      'description': 'Fresh Local Apple Slices with Sunflower Seed Butter',
#      'cals': '570 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '25g carbs',
#      'sugars': '17g sugars',
#      'proteins': '7g proteins'},
#     'Create Your Own Sandwich Station': {'item': 'Create Your Own Sandwich Station',
#      'description': 'Create Your Own Sandwich Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup',
#      'description': 'Rich homemade tomato soup with cream and fresh basil',
#      'cals': '205 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '12g sugars',
#      'proteins': '5g proteins'},
#     'Turkey & Brown Rice Soup': {'item': 'Turkey & Brown Rice Soup',
#      'cals': '75 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '2g sugars',
#      'proteins': '5g proteins'},
#     'Tomato Dijon Pot Roast': {'item': 'Tomato Dijon Pot Roast',
#      'description': 'Tender beef braised in a flavorful tomato Dijon sauce',
#      'cals': '255 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '9g carbs',
#      'sugars': '3g sugars',
#      'proteins': '31g proteins'},
#     'Chocolate Chip Blondie': {'item': 'Chocolate Chip Blondie',
#      'cals': '260 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '27g sugars',
#      'proteins': '2g proteins'},
#     'Lentil Soup': {'item': 'Lentil Soup',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '3g sugars',
#      'proteins': '5g proteins'},
#     'Roasted Garlic Potatoes': {'item': 'Roasted Garlic Potatoes',
#      'description': 'Oven-roasted red potatoes tossed with roasted garlic',
#      'cals': '85 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '1g sugars',
#      'proteins': '2g proteins'},
#     'Steamed Green Beans': {'item': 'Steamed Green Beans',
#      'description': 'Steamed fresh whole green beans',
#      'cals': '30 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '6g carbs',
#      'sugars': '3g sugars',
#      'proteins': '2g proteins'},
#     'Japchae': {'item': 'Japchae',
#      'cals': '175 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '29g carbs',
#      'sugars': '3g sugars',
#      'proteins': '6g proteins'},
#     'Kimchi Jigae': {'item': 'Kimchi Jigae',
#      'cals': '115 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '7g carbs',
#      'sugars': '2g sugars',
#      'proteins': '12g proteins'}}},
#   'west': {'breakfast': {'Scrambled Eggs': {'item': 'Scrambled Eggs',
#      'description': 'Cage Free egs scrambled with salt and pepper',
#      'cals': '185 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '16g proteins'},
#     'Turkey Sausage Patty': {'item': 'Turkey Sausage Patty',
#      'description': 'Sizzling hot golden brown turkey sausage patty',
#      'cals': '90 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Cheddar Grits': {'item': 'Cheddar Grits',
#      'description': 'Creamy Cheddar grits with green onions, spices and a hint of hot sauce',
#      'cals': '145 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Chocolate Chip Buttermilk Pancakes': {'item': 'Chocolate Chip Buttermilk Pancakes'},
#     'Pineapple-Mint Smoothie': {'item': 'Pineapple-Mint Smoothie',
#      'description': 'Pineapple and fresh banana blended with creamy vanilla yogurt, lemon and apple juices and fresh mint',
#      'cals': '145 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '35g carbs',
#      'sugars': '24g sugars',
#      'proteins': '2g proteins'},
#     'Create Your Own Omelet Station': {'item': 'Create Your Own Omelet Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Old Fashioned Oatmeal': {'item': 'Old Fashioned Oatmeal',
#      'description': 'Homestyle oatmeal cereal',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Hard Boiled Egg': {'item': 'Hard Boiled Egg',
#      'description': 'Peeled hard-cooked egg',
#      'cals': '70 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '1g sugars',
#      'proteins': '6g proteins'},
#     'Banana Muffin': {'item': 'Banana Muffin',
#      'cals': '260 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '37g carbs',
#      'sugars': '16g sugars',
#      'proteins': '4g proteins'},
#     'Apple Cinnamon Bread': {'item': 'Apple Cinnamon Bread',
#      'cals': '225 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '32g carbs',
#      'sugars': '18g sugars',
#      'proteins': '1g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'}},
#    'lunch': {'Vegan Firecracker Tofu': {'item': 'Vegan Firecracker Tofu',
#      'cals': '255 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '7g sugars',
#      'proteins': '11g proteins'},
#     'Brown Rice': {'item': 'Brown Rice',
#      'description': 'Tender cooked brown rice',
#      'cals': '110 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '23g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'cals': '245 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '4g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Vegetable Pizza': {'item': 'Vegan Vegetable Pizza',
#      'description': 'Vegan Vegetable Pizza',
#      'cals': '245 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '45g carbs',
#      'sugars': '4g sugars',
#      'proteins': '9g proteins'},
#     'Hawaiian Pizza': {'item': 'Hawaiian Pizza',
#      'description': 'Ham, pineapple, mozzarella cheese and pizza sauce on a golden brown crust',
#      'cals': '225 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '25g carbs',
#      'sugars': '6g sugars',
#      'proteins': '15g proteins'},
#     'Backyard BBQ Burger': {'item': 'Backyard BBQ Burger',
#      'description': 'Angus burger with cheddar, coleslaw, red onion and BBQ sauce on a toasted roll',
#      'cals': '470 cals',
#      'saturated fat': '11g saturated fat',
#      'carbs': '31g carbs',
#      'sugars': '9g sugars',
#      'proteins': '29g proteins'},
#     'Crunchy Onion Rings': {'item': 'Crunchy Onion Rings',
#      'description': 'Crunchy deep-fried batter-dipped and panko crumb-coated onion rings',
#      'cals': '275 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '60g carbs',
#      'sugars': '8g sugars',
#      'proteins': '6g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Tortilla Chips': {'item': 'Tortilla Chips',
#      'description': 'House-made crunchy corn tortilla chips',
#      'cals': '145 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '22g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Fire Roasted Pepper Sauce': {'item': 'Fire Roasted Pepper Sauce',
#      'description': 'Fire Roasted Red Peppers blended with dried ancho and habanero',
#      'cals': '20 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Smokey Pineapple Hot Sauce': {'item': 'Smokey Pineapple Hot Sauce',
#      'description': 'Char-grilled pineapples & jalapeño blended with chipotle and a citrus blend .',
#      'cals': '10 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '2g sugars',
#      'proteins': '0g proteins'},
#     'Queso Fresco': {'item': 'Queso Fresco',
#      'description': 'Crumbled queso fresco',
#      'cals': '405 cals',
#      'saturated fat': '20g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '4g sugars',
#      'proteins': '24g proteins'},
#     'Dragon Fruit Agua Fresca': {'item': 'Dragon Fruit Agua Fresca',
#      'description': 'Fresh dragon fruit mixed with lime juice & agave',
#      'cals': '70 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '15g carbs',
#      'sugars': '6g sugars',
#      'proteins': '1g proteins'},
#     'Salsa Roja': {'item': 'Salsa Roja'},
#     'Meatballs': {'item': 'Meatballs',
#      'description': 'Homemade meatballs seasoned with Italian seasonings and Parmesan',
#      'cals': '115 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '2g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'White Rice': {'item': 'White Rice',
#      'description': 'Slow-simmered long grain white rice',
#      'cals': '120 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '26g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Garlic Oregano Baguette': {'item': 'Garlic Oregano Baguette',
#      'description': 'Warm crusty baguette brushed with garlic-oregano oil',
#      'cals': '375 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Fresh Homemade Pasta': {'item': 'Fresh Homemade Pasta',
#      'cals': '100 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Marinara Sauce': {'item': 'Marinara Sauce'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup',
#      'description': 'Rich homemade tomato soup with cream and fresh basil',
#      'cals': '205 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '12g sugars',
#      'proteins': '5g proteins'},
#     'Chicken Noodle Soup': {'item': 'Chicken Noodle Soup',
#      'description': 'Tender chicken, egg noodles and vegetables simmered in savory chicken stock',
#      'cals': '90 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '2g sugars',
#      'proteins': '6g proteins'},
#     'Seasoned Roast Beef': {'item': 'Seasoned Roast Beef',
#      'description': 'Oven-roasted eye round of beef coated with a peppery seasoning',
#      'cals': '155 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '25g proteins'},
#     'Rosemary Roast Potatoes': {'item': 'Rosemary Roast Potatoes',
#      'cals': '85 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '17g carbs',
#      'sugars': '1g sugars',
#      'proteins': '2g proteins'},
#     'Green Beans': {'item': 'Green Beans',
#      'cals': '40 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '5g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Vegan Pumpkin Cake': {'item': 'Vegan Pumpkin Cake',
#      'description': 'Freshly-baked vegan pumpkin spice cake with raisins and walnuts',
#      'cals': '265 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '39g carbs',
#      'sugars': '23g sugars',
#      'proteins': '2g proteins'},
#     'Apricot Turnover': {'item': 'Apricot Turnover',
#      'cals': '280 cals',
#      'saturated fat': '10g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '1g sugars',
#      'proteins': '5g proteins'},
#     'Oreo Brownie': {'item': 'Oreo Brownie',
#      'cals': '205 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '24g sugars',
#      'proteins': '2g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Spicy Avocado Slaw Wrap': {'item': 'Spicy Avocado Slaw Wrap',
#      'description': 'Avocados, Sriracha slaw and cucumbers with chipotle dressing in flour tortilla',
#      'cals': '165 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '25g carbs',
#      'sugars': '2g sugars',
#      'proteins': '3g proteins'},
#     'Trail Mix': {'item': 'Trail Mix',
#      'description': 'Crunchy low fat granola',
#      'cals': '215 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '18g sugars',
#      'proteins': '3g proteins'},
#     'Hummus with Veggie': {'item': 'Hummus with Veggie',
#      'description': 'Creamy hummus with celery, carrot and cucumber dippers',
#      'cals': '120 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '3g sugars',
#      'proteins': '4g proteins'},
#     'Creamy Tuna Salad': {'item': 'Creamy Tuna Salad'},
#     'Guacamole': {'item': 'Guacamole'},
#     'Create Your Own Sandwich Station': {'item': 'Create Your Own Sandwich Station',
#      'description': 'Create Your Own Sandwich Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Mango Quinoa Salad': {'item': 'Mango Quinoa Salad',
#      'description': 'Quinoa, mango, cranberries, jalapeno and green onions on a bed of greens topped with toasted almonds',
#      'cals': '350 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '32g carbs',
#      'sugars': '15g sugars',
#      'proteins': '6g proteins'},
#     'Blue Cheese Dressing': {'item': 'Blue Cheese Dressing'},
#     'Create Your Own Salad Bar': {'item': 'Create Your Own Salad Bar',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'}},
#    'dinner': {'Korean Stir Fried BBQ Tofu': {'item': 'Korean Stir Fried BBQ Tofu',
#      'description': 'Stir-fried tofu with fresh broccoli, cabbage, onion, carrot and celery in chili garlic sauce',
#      'cals': '130 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '22g carbs',
#      'sugars': '15g sugars',
#      'proteins': '4g proteins'},
#     'Gardenburger Veggie Burger': {'item': 'Gardenburger Veggie Burger',
#      'description': 'Grilled black bean burger on a bun',
#      'cals': '210 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '37g carbs',
#      'sugars': '3g sugars',
#      'proteins': '14g proteins'},
#     'Quinoa': {'item': 'Quinoa',
#      'description': 'Nutty-flavored grain',
#      'cals': '135 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '23g carbs',
#      'sugars': '0g sugars',
#      'proteins': '5g proteins'},
#     'Cheese Pizza': {'item': 'Cheese Pizza',
#      'cals': '245 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '34g carbs',
#      'sugars': '4g sugars',
#      'proteins': '15g proteins'},
#     'Vegan Sausage and Pepper Pizza': {'item': 'Vegan Sausage and Pepper Pizza',
#      'description': 'Beyond sausage and bell peppers with vegan mozzarella on hand stretched crust',
#      'cals': '270 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '4g sugars',
#      'proteins': '9g proteins'},
#     'Vegan Cheese Pizza': {'item': 'Vegan Cheese Pizza',
#      'description': 'Vegan mozzarella and tomato sauce on hand stretched crust',
#      'cals': '240 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '41g carbs',
#      'sugars': '4g sugars',
#      'proteins': '7g proteins'},
#     'Philly Cheesesteak': {'item': 'Philly Cheesesteak',
#      'description': 'Philly cheesesteak with fried onions and American cheese',
#      'cals': '595 cals',
#      'saturated fat': '13g saturated fat',
#      'carbs': '44g carbs',
#      'sugars': '5g sugars',
#      'proteins': '31g proteins'},
#     'Local Homestyle French Fries': {'item': 'Local Homestyle French Fries',
#      'cals': '315 cals',
#      'saturated fat': '4g saturated fat',
#      'carbs': '30g carbs',
#      'sugars': '0g sugars',
#      'proteins': '3g proteins'},
#     'Grill Works': {'item': 'Grill Works',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Lemon Herb Chicken': {'item': 'Lemon Herb Chicken',
#      'cals': '155 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '1g sugars',
#      'proteins': '25g proteins'},
#     'Mashed Sweet Potato': {'item': 'Mashed Sweet Potato',
#      'description': 'Sweet potatoes mashed with brown sugar and cinnamon',
#      'cals': '90 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '18g carbs',
#      'sugars': '16g sugars',
#      'proteins': '0g proteins'},
#     'Cauliflower': {'item': 'Cauliflower',
#      'description': 'Steamed fresh cauliflower',
#      'cals': '15 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '1g sugars',
#      'proteins': '1g proteins'},
#     'Create Your Own': {'item': 'Create Your Own'},
#     'Tortilla Chips': {'item': 'Tortilla Chips',
#      'description': 'House-made crunchy corn tortilla chips',
#      'cals': '145 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '22g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Fire Roasted Pepper Sauce': {'item': 'Fire Roasted Pepper Sauce',
#      'description': 'Fire Roasted Red Peppers blended with dried ancho and habanero',
#      'cals': '20 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Smokey Pineapple Hot Sauce': {'item': 'Smokey Pineapple Hot Sauce',
#      'description': 'Char-grilled pineapples & jalapeño blended with chipotle and a citrus blend .',
#      'cals': '10 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '2g sugars',
#      'proteins': '0g proteins'},
#     'Queso Fresco': {'item': 'Queso Fresco',
#      'description': 'Crumbled queso fresco',
#      'cals': '405 cals',
#      'saturated fat': '20g saturated fat',
#      'carbs': '4g carbs',
#      'sugars': '4g sugars',
#      'proteins': '24g proteins'},
#     'Mango-Lemon Agua Fresca': {'item': 'Mango-Lemon Agua Fresca',
#      'description': 'Fresh mango mixed with lemon juice & agave',
#      'cals': '115 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '30g carbs',
#      'sugars': '24g sugars',
#      'proteins': '0g proteins'},
#     'Salsa Roja': {'item': 'Salsa Roja'},
#     'White Rice': {'item': 'White Rice',
#      'description': 'Slow-simmered long grain white rice',
#      'cals': '120 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '26g carbs',
#      'sugars': '0g sugars',
#      'proteins': '2g proteins'},
#     'Garlic Oregano Baguette': {'item': 'Garlic Oregano Baguette',
#      'description': 'Warm crusty baguette brushed with garlic-oregano oil',
#      'cals': '375 cals',
#      'saturated fat': '3g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '0g sugars',
#      'proteins': '7g proteins'},
#     'Fresh Homemade Pasta': {'item': 'Fresh Homemade Pasta',
#      'cals': '100 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '20g carbs',
#      'sugars': '1g sugars',
#      'proteins': '4g proteins'},
#     'Diced Chicken': {'item': 'Diced Chicken',
#      'description': 'Diced roasted fresh chicken breasts and thighs',
#      'cals': '150 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '1g carbs',
#      'sugars': '0g sugars',
#      'proteins': '21g proteins'},
#     'Pesto Sauce': {'item': 'Pesto Sauce'},
#     'Chicken Noodle Soup': {'item': 'Chicken Noodle Soup',
#      'description': 'Tender chicken, egg noodles and vegetables simmered in savory chicken stock',
#      'cals': '90 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '2g sugars',
#      'proteins': '6g proteins'},
#     'Creamy Tomato Basil Soup': {'item': 'Creamy Tomato Basil Soup'},
#     'Fresh Steamed Vegetables': {'item': 'Fresh Steamed Vegetables',
#      'description': 'Lightly seasoned steamed fresh green and yellow squash, broccoli, cauliflower and bell pepper',
#      'cals': '20 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '3g carbs',
#      'sugars': '2g sugars',
#      'proteins': '1g proteins'},
#     'Dirty Rice': {'item': 'Dirty Rice'},
#     'Vegan Vanilla Crumb Cake': {'item': 'Vegan Vanilla Crumb Cake',
#      'cals': '275 cals',
#      'saturated fat': '2g saturated fat',
#      'carbs': '42g carbs',
#      'sugars': '23g sugars',
#      'proteins': '3g proteins'},
#     'Funfetti Bars': {'item': 'Funfetti Bars',
#      'description': 'Funfetti blondies',
#      'cals': '335 cals',
#      'saturated fat': '6g saturated fat',
#      'carbs': '50g carbs',
#      'sugars': '34g sugars',
#      'proteins': '2g proteins'},
#     'Double Fudge Brownie': {'item': 'Double Fudge Brownie',
#      'description': 'Chewy chocolate fudge dessert bar frosted with chocolate icing',
#      'cals': '355 cals',
#      'saturated fat': '5g saturated fat',
#      'carbs': '57g carbs',
#      'sugars': '45g sugars',
#      'proteins': '3g proteins'},
#     'Assorted Cookies': {'item': 'Assorted Cookies',
#      'description': 'Freshly baked assorted cookies',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Trail Mix': {'item': 'Trail Mix',
#      'description': 'Crunchy low fat granola',
#      'cals': '215 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '43g carbs',
#      'sugars': '18g sugars',
#      'proteins': '3g proteins'},
#     'Hummus with Veggie': {'item': 'Hummus with Veggie',
#      'description': 'Creamy hummus with celery, carrot and cucumber dippers',
#      'cals': '120 cals',
#      'saturated fat': '1g saturated fat',
#      'carbs': '11g carbs',
#      'sugars': '3g sugars',
#      'proteins': '4g proteins'},
#     'Creamy Tuna Salad': {'item': 'Creamy Tuna Salad'},
#     'Guacamole': {'item': 'Guacamole'},
#     'Create Your Own Sandwich Station': {'item': 'Create Your Own Sandwich Station',
#      'description': 'Create Your Own Sandwich Station',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'},
#     'Blue Cheese Dressing': {'item': 'Blue Cheese Dressing'},
#     'Create Your Own Salad Bar': {'item': 'Create Your Own Salad Bar',
#      'cals': '0 cals',
#      'saturated fat': '0g saturated fat',
#      'carbs': '0g carbs',
#      'sugars': '0g sugars',
#      'proteins': '0g proteins'}}}}}

# %%
page = requests.get("https://www.bu.edu/dining/location/marciano/#menu")
id = str(today)+"-"+"dinner"
results = soup.find(id=id)
xs = results.find_all("li", class_="menu-item menu-main menu-has-warning")
for x in xs:
    print(x.find("h4", class_="js-nutrition-open-alias menu-item-title").text)
    z = x.find("ul", class_="menu-nutrition-overview")
#     if not z==None:
#         print(z.text)
#     else:
#         z = x.find("li", class_="nutrition-label-cyo")
#         print(z)
    for line in z:
        print(line.text)
        print("break")
    break
# Out:
# Ultimate Fudge Brownie
#
#
# break
# 195 cals
# break
#
#
# break
# 2g saturated fat
# break
#
#
# break
# 33g carbs
# break
#
#
# break
# 23g sugars
# break
#
#
# break
# 2g proteins
# break
#
#
# break
