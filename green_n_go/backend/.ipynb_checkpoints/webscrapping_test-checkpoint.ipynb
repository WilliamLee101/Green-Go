# %%
import requests
from datetime import date

meals_time = ["breakfast", "lunch", "dinner"]
today = date.today()
print(today)

URLs = {"marciano": "https://www.bu.edu/dining/location/marciano/#menu", "warren": "https://www.bu.edu/dining/location/warren/#menu", "west":"https://www.bu.edu/dining/location/west/#menu"}
dining_halls = ["marciano", "warren", "west"]
updated_menu = {}
updated_menu[str(today)] = {}

# print(page.text)
# Out:
# 2023-03-12

# %%
import requests
from datetime import date

meals_time = ["breakfast", "lunch", "dinner"]
today = date.today()
URLs = {"marciano": "https://www.bu.edu/dining/location/marciano/#menu", "warren": "https://www.bu.edu/dining/location/warren/#menu", "west":"https://www.bu.edu/dining/location/west/#menu"}


# print(page.text)
from bs4 import BeautifulSoup
updated_menu = {}
updated_menu[str(today)] = {}
details = ["cals", "saturated fat", "carbs", "sugars", "proteins"]

for dining_hall in URLs.keys():
    URL = URLs[dining_hall]
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    updated_menu[str(today)][dining_hall] = {}
    
    for meal_time in meals_time:
        id = str(today)+"-"+meal_time
        updated_menu[str(today)][dining_hall][meal_time] = {}
        results = soup.find(id=id)
        xs = results.find_all("li", class_="menu-item menu-main menu-has-warning")
        for x in xs:
            title = x.find("h4", class_="js-nutrition-open-alias menu-item-title").text
            updated_menu[str(today)][dining_hall][meal_time][title] = {}
            updated_menu[str(today)][dining_hall][meal_time][title]["item"] = title
            descripton = x.find("p", class_="menu-description")
            if descripton != None:
                descripton = descripton.text
                descripton = descripton.replace("\t\t\t\t", "")
                descripton = descripton.replace("\n\t\t\t\t\t", "")
                descripton = descripton.replace("\n\t", "")
                updated_menu[str(today)][dining_hall][meal_time][title]["description"] = descripton
            z = x.find("ul", class_="menu-nutrition-overview")
            if not z==None:
                for line in z:
                    line = line.text
                    for detail in details:
                        if detail in line:
                            updated_menu[str(today)][dining_hall][meal_time][title][detail]=line

# %%
import requests
base_url = "https://www.bu.edu/dining/api/locations/marciano/menu/2023-03-16/"
response = requests.get(base_url)
response.json()
# Out:
# {'api_url': 'https://www.bu.edu/dining/api/locations/marciano/menu/2023-03-16/',
#  'date': '2023-03-16',
#  'location': {'api_url': 'https://www.bu.edu/dining/api/locations/marciano/',
#   'slug': '',
#   'name': 'The Fresh Food Co. at Marciano Commons'},
#  'meal_groups': {'Breakfast': {'name': 'Breakfast',
#    'stations': [{'station_name': 'Bakery',
#      'menu_items': [{'id': 'M15668',
#        'name': 'Raisins',
#        'description': 'Seedless raisins',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Seedless Raisins (raisins).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '135',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '32',
#        'serving_type_code': 21},
#       {'id': 'M21743',
#        'name': 'Brown Sugar',
#        'description': 'Light brown sugar',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Brown Sugar (brown sugar [when produced at Chalmette or Crockett facilities] sugar, molasses [when produced at South Bay facility]).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '55',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '14',
#        'serving_type_code': 23},
#       {'id': 'L322318',
#        'name': 'Dried Fruit Mix',
#        'description': 'Dried Fruit Medley of Dark Raisins, Natural Diced Apricot, Cranberries, Toasted Coconut,',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Dried Apricots (apricots, sulfur dioxide [added for color retention and as a preservative]).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '70',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '17',
#        'serving_type_code': 21},
#       {'id': 'M34520',
#        'name': 'Old Fashioned Oatmeal',
#        'description': 'Homestyle oatmeal cereal',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': True,
#        'ingredients': 'Tap Water, Rolled Oats.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '110',
#        'saturated_fat': '0',
#        'protein': '4',
#        'carbohydrates': '20',
#        'serving_type_code': 9},
#       {'id': 'L95616',
#        'name': 'Berry Compote',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Blueberries, Frozen Raspberries, Tap Water, White Sugar, Unsalted Butter (pasteurized cream, natural flavoring).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '300',
#        'saturated_fat': '7',
#        'protein': '1',
#        'carbohydrates': '50',
#        'serving_type_code': 17},
#       {'id': 'L104377',
#        'name': 'Cranberry Orange Muffin',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': True,
#        'ingredients': 'Whole Wheat Muffin Mix (whole wheat flour bleached, sugar, palm oil, modified corn starch. contains 2% or less of: leavening [sodium acid pyrophosphate, baking soda, monocalcium phosphate], dextrose, salt, nonfat milk, eggs with sodium silicoaluminate, mono and diglycerides, xanthan gum, soy flour), Orange Juice (Orange juice concentrate, treated water, apple juice concentrate, citric acid, natural flavor, sodium benzoate [preserves freshness], potassium sorbate [preserves freshness], ascorbic acid), Liquid Whole Egg (whole eggs, citric acid, 0.15% water added as carrier for citric acid. citric acid added to preserve color), Frozen Cranberries, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Tap Water, Orange Peel.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '225',
#        'saturated_fat': '3',
#        'protein': '3',
#        'carbohydrates': '31',
#        'serving_type_code': 9},
#       {'id': 'L256088',
#        'name': 'Lemon Blueberry Loaf',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Pound Cake Mix (sugar, enriched flour bleached [wheat flour, niacin, iron, thiamin mononitrate, riboflavin, folic acid], palm oil, corn syrup solids. contains 2% or less of: egg yolk with sodium silicoaluminate, eggs with sodium silicoaluminate, egg white, salt, leavening [baking soda, monocalcium phosphate, sodium acid pyrophosphate], whey protein concentrate, propylene glycol mono and diesters, xanthan gum, mono and diglycerides, soy lecithin, whey, natural flavor, annatto and turmeric extract color), Confectioner Sugar (sugar, corn starch), Blueberries, Tap Water, Lemon Juice (Sahara Burst: filtered water, lemon juice concentrate, sodium bisulfite [preservative], sodium benzoate [preservative], lemon oil) (Viaggio: water, lemon juice concentrated, sodium benzoate, sodium bisulfite, lemon oil), Sour Cream (cultured milk, cream, modified corn starch, guar gum, sodiumcitrate, carrageenan, locust bean gum), Lemon Zest (chopped lemon peels, cane sugar, natural lemon flavor).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '300',
#        'saturated_fat': '4',
#        'protein': '3',
#        'carbohydrates': '53',
#        'serving_type_code': 17}]},
#     {'station_name': 'Grill',
#      'menu_items': [{'id': 'L264435',
#        'name': 'Scrambled Eggs',
#        'description': 'Cage Free egs scrambled with salt and pepper',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Liquid Whole Egg (whole eggs, citric acid, 0.15% water added as carrier for citric acid. citric acid added to preserve color), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '185',
#        'saturated_fat': '4',
#        'protein': '16',
#        'carbohydrates': '0',
#        'serving_type_code': 9},
#       {'id': 'M20666',
#        'name': 'Bananas Foster French Toast',
#        'description': 'Thick-cut French toast topped with warm bananas cooked in brown sugar, cinnamon and butter',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Texas Toast (enriched flour [wheat flour unbleached, malted barley flour, niacin, reduced iron, thiamin mononitrate, riboflavin, folic acid], water, sugar, soybean oil, contains less than 2% of : calcium propionate, corn flour, turmeric, mono-& diglycerides, paprika, natural & artificial flavors, monoglycerides, propionic acid, phosphoric acid, ascorbic acid, wheat gluten, enzymes, salt, yeast), Liquid Whole Egg (whole eggs, citric acid, 0.15% water added as carrier for citric acid. citric acid added to preserve color), 2% Milk (reduced fat milk, ascorbic acid [vitamin C], vitamin A palmitate and vitamin D3), Brown Sugar (brown sugar [when produced at Chalmette or Crockett facilities] sugar, molasses [when produced at South Bay facility]), Unsalted Butter (pasteurized cream, natural flavoring), Imitation Vanilla Extract (water, caramel color, vanillin, ethyl vanillin, and 0.1% potassium sorbate [added as a preservative]), Ground Cinnamon.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '355',
#        'saturated_fat': '8',
#        'protein': '8',
#        'carbohydrates': '43',
#        'serving_type_code': 9},
#       {'id': 'M35627',
#        'name': 'Pork Sausage Patty',
#        'description': 'Pork sausage patty',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Pork Sausage Patty (pork, contains 2% or less of: water, salt, corn syrup solids, flavorings, sugar, dextrose, BHT, propyl gallate, citric acid).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '180',
#        'saturated_fat': '6',
#        'protein': '4',
#        'carbohydrates': '0',
#        'serving_type_code': 14},
#       {'id': 'M10344',
#        'name': 'Santa Fe Potatoes',
#        'description': 'Pan-fried diced red potatoes, red peppers and onions seasoned with a Southwest spice blend',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Red Potatoes, Red Bell Pepper, Yellow Onion, Unsalted Butter (pasteurized cream, natural flavoring), Taco Seasoning (spices [including chile pepper, cumin, paprika, oregano], onion, whey [milk], salt, sugar, garlic, potato starch, and citric acid).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '200',
#        'saturated_fat': '5',
#        'protein': '3',
#        'carbohydrates': '28',
#        'serving_type_code': 2}]},
#     {'station_name': 'Mediterranean',
#      'menu_items': [{'id': 'L92977',
#        'name': 'Tofu Scramble',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Firm Tofu (Soga: water, soybeans, less than 2% of firming agents [calcium sulfate, magnesium chloride, and/or glucono delta lactone])(Nasoya: water, organic soybeans, less than 2% of magnesium chloride, calcium sulfate), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Turmeric, Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '185',
#        'saturated_fat': '3',
#        'protein': '11',
#        'carbohydrates': '8',
#        'serving_type_code': 11},
#       {'id': 'L274831',
#        'name': 'Create Your Own Omelet Station',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': '',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '0',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '0',
#        'serving_type_code': 9}]},
#     {'station_name': 'Mediterranean Create Your Own',
#      'menu_items': [{'id': 'M11769',
#        'name': 'Diced Tomatoes',
#        'description': 'Diced fresh tomatoes',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Red Tomatoes.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M14258',
#        'name': 'Shredded Cheddar Cheese',
#        'description': 'Shredded Cheddar cheese',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Shredded Cheddar Cheese (pasteurized milk, cheese culture, salt, enzymes, annatto [if colored], potato starch and powdered cellulose added to prevent caking).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '110',
#        'saturated_fat': '5',
#        'protein': '7',
#        'carbohydrates': '0',
#        'serving_type_code': 20},
#       {'id': 'M19960',
#        'name': 'Sauteed Onions',
#        'description': 'Sauteed onions',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Yellow Onion, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '50',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '5',
#        'serving_type_code': 3},
#       {'id': 'M20323',
#        'name': 'Diced Green Peppers',
#        'description': 'Diced fresh green peppers',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Green Bell Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '15',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '4',
#        'serving_type_code': 3},
#       {'id': 'M15456',
#        'name': 'Fried Egg',
#        'description': 'Fresh cage-free eggs fried to order',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Cage Free Eggs, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '95',
#        'saturated_fat': '2',
#        'protein': '6',
#        'carbohydrates': '0',
#        'serving_type_code': 9},
#       {'id': 'M3697',
#        'name': 'Sauteed Mushrooms',
#        'description': 'Sauteed quartered fresh mushrooms',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Mushrooms, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '55',
#        'saturated_fat': '1',
#        'protein': '1',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'L95596',
#        'name': 'Egg Whites',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Egg Whites.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '60',
#        'saturated_fat': '0',
#        'protein': '12',
#        'carbohydrates': '0',
#        'serving_type_code': 9}]},
#     {'station_name': 'Gluten Free Kitchen',
#      'menu_items': [{'id': 'L336834',
#        'name': 'Breakfast Fried Rice',
#        'description': 'Fried rice with scrambled eggs, bacon, bok choy, red pepper and hash brown potatoes',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Tap Water, Bok Choy, Liquid Whole Egg (whole eggs, citric acid, 0.15% water added as carrier for citric acid. citric acid added to preserve color), Jasmine Rice (Thai hom mali jasmine rice), Shredded Hashbrown (potatoes, dextrose, disodium pyrophosphate [added to maintain color], potassium sorbate [added to maintain freshness]), Bacon Sliced (pork cured with: water, [sea] salt, contains less than 2% of the following: [cane] sugar, celery powder, sodium phosphates, sodium erythorbate, sodium nitrite), Red Bell Pepper, Unsalted Butter (pasteurized cream, natural flavoring), Ketchup (tomato concentrate from red ripe tomatoes, distilled vinegar, high fructose corn syrup, corn syrup, salt, spice, onion powder, natural flavoring), Yellow Onion, GF Tamari Soy Sauce (water, soybeans, salt, sugar), Rice Wine Vinegar (rice wine vinegar [diluted with water to 4.5% acidity], sugar, salt, potassium metabisulfite [preservative], caramel color. contains sulfites), Sriracha (salted red chili pepper [red chili pepper, salt], sugar, garlic, salt, water, acetic acid, lactic acid, xanthan gum, citric acid, potassium sorbate [preservative], ascorbic acid), Sesame Seeds, Roasted Garlic Flavor Concentrate (roasted garlic, water, sauteed vegetable puree mix [carrots, onions, celery], dextrose, salt, dried garlic, 2% or less of canola oil, dried onions, xanthan gum, potassium chloride, celery juice concentrate).',
#        'is_glutenfree': True,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '275',
#        'saturated_fat': '8',
#        'protein': '10',
#        'carbohydrates': '24',
#        'serving_type_code': 9}]},
#     {'station_name': 'Salad Bar',
#      'menu_items': [{'id': 'M32895',
#        'name': 'Sliced Watermelon',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Watermelon.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '55',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '13',
#        'serving_type_code': 21}]},
#     {'station_name': 'Salad Bar Create Your Own',
#      'menu_items': [{'id': 'M10503',
#        'name': 'Lemon Wedges',
#        'description': 'Fresh lemon wedges',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Lemon.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '5',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '1',
#        'serving_type_code': 3},
#       {'id': 'M14598',
#        'name': 'Honeydew Melon',
#        'description': 'Cubed honeydew melon',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Honeydew.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '30',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '8',
#        'serving_type_code': 21},
#       {'id': 'M14599',
#        'name': 'Cantaloupe',
#        'description': 'Cubed fresh cantaloupe',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Cantaloupe (fresh cantaloupe).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '30',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '7',
#        'serving_type_code': 21},
#       {'id': 'M14528',
#        'name': 'Cottage Cheese',
#        'description': 'Creamy cottage cheese',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Fat Free Cottage Cheese (cultured pasteurized skim milk, nonfat milk, whey protein concentrate, whey, maltodextrin, salt, modified corn starch, color added, potassium sorbate and carbon dioxide [to maintain freshness], guar gum, carrageenan, locust bean gum, natural flavor, phosphoric acid, vitamin A palmitate and enzymes).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '80',
#        'saturated_fat': '0',
#        'protein': '13',
#        'carbohydrates': '7',
#        'serving_type_code': 20},
#       {'id': 'L97658',
#        'name': 'Sargent Choice Granola',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': True,
#        'ingredients': 'Rolled Oats, Tap Water, Pancake Syrup (high fructose corn syrup, corn syrup, water, contains 2% or less of: salt, cellulose gum, molasses, potassium sorbate [preservative], sodium hexametaphosphate, natural and artificial flavor, caramel color, corn syrup, artificial flavor, citric acid, caramel color, mono and diglycerides), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Honey, Seedless Raisins (raisins), Dried Cranberries (Craisins) (cranberries, sugar, citric acid, elderberry juice concentrate, sunflower oil), Whole Wheat Flour (whole wheat flour), Imitation Vanilla Extract (water, caramel color, vanillin, ethyl vanillin, and 0.1% potassium sorbate [added as a preservative]), Ground Cinnamon.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '190',
#        'saturated_fat': '1',
#        'protein': '3',
#        'carbohydrates': '32',
#        'serving_type_code': 1},
#       {'id': 'L274504',
#        'name': 'Plain Yogurt',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Plain Non-Fat Yogurt (cultured pasteurized skim milk*, modified corn starch, carrageenan, pectin,Vitamins A, C, D, E. *adds a trivial amount of fat) (cultured pasteurized organic low fat milk, pectin, vitamin D3) (cultured grade A non fat milk).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '55',
#        'saturated_fat': '0',
#        'protein': '5',
#        'carbohydrates': '9',
#        'serving_type_code': 20},
#       {'id': 'L274502',
#        'name': 'Vanilla Yogurt',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Vanilla Yogurt (Yoplait: cultured grade a low fat milk, sugar, modified corn starch. contains less than 1% of: corn starch, potassium sorbate added to maintain freshness, natural flavor, vitamin a acetate, vitamin d3) (Dannon: cultured grade a non fat milk, cane sugar, modified food starch, water, contains less than 1% of natural flavors, vegetable juice [for color], agar agar, citric acid, sodium citrate, potassium sorbate [to maintain freshness], vitamin d3).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '100',
#        'saturated_fat': '0',
#        'protein': '3',
#        'carbohydrates': '21',
#        'serving_type_code': 20},
#       {'id': 'L274503',
#        'name': 'Strawberry Yogurt',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Strawberry Low-Fat Yogurt (Yoplait: cultured grade a low fat milk, sugar, modified corn starch. contains 1% or less of: corn starch, citric acid, vegetable juice [for color], natural flavor, potassium sorbate added to maintain freshness, vitamin a acetate, vitamin d3) (Dannon: cultured grade a non fat milk, cane sugar, water, modified food starch, contains less than 1% of natural flavors, beta carotene and black carrot juice concentrate (for color), malic acid, sodium citrate, potassium sorbate [to maintain freshness], vitamin d3).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '100',
#        'saturated_fat': '0',
#        'protein': '3',
#        'carbohydrates': '21',
#        'serving_type_code': 20}]}]},
#   'Brunch': {'name': 'Brunch', 'stations': []},
#   'Lunch': {'name': 'Lunch',
#    'stations': [{'station_name': 'Bakery',
#      'menu_items': [{'id': 'L273977',
#        'name': 'Banana Cake',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Banana, Sweetened Applesauce (apple, high fructose corn syrup, corn syrup, water, ascorbic acid), Turbinado Sugar, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), All Purpose Flour (bleached wheat flour, malted barley flour, niacin, iron, thiamin mononitrate, riboflavin, folic), Whole Wheat Flour (whole wheat flour), Tap Water, Brown Sugar (brown sugar [when produced at Chalmette or Crockett facilities] sugar, molasses [when produced at South Bay facility]), Seedless Raisins (raisins), Egg Replacer (potato starch, tapioca flour, leavening [calcium lactate, calcium carbonate, cream of tartar], cellulose gum, modified cellulose), Baking Soda (sodium bicarbonate), Imitation Vanilla Extract (water, caramel color, vanillin, ethyl vanillin, and 0.1% potassium sorbate [added as a preservative]), Confectioner Sugar (sugar, corn starch), Ground Cinnamon, Kosher Salt (salt, yellow prussiate of soda [YPS]), Double Acting Baking Powder (corn starch, sodium bicarbonate, monocalcium phosphate), Ground Nutmeg (nutmeg), Ground Clove.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '275',
#        'saturated_fat': '2',
#        'protein': '3',
#        'carbohydrates': '42',
#        'serving_type_code': 17},
#       {'id': 'M2340',
#        'name': 'Crispy Cereal Bar',
#        'description': 'Crispy dessert bar with crisp rice cereal and marshmallows',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Mini marshmallows (corn syrup, sugar, modified cornstarch, dextrose, water, contains less than 2% of gelatin, tetrasodium pyrophosphate [whipping aid], natural and artificial flavor, blue 1), Rice Krispies Cereal (rice, sugar, contains 2% or less of salt, malt flavor. vitamins and minerals: iron [ferric phosphate], niacinamide, vitamin B6 [pyridoxine hydrochloride], vitamin B2 [riboflavin], vitamin B1 [thiamin hydrochloride], folic acid, vitamin D3, vitamin B12.), Margarine (oil blend [palm, soybean, canola, and olive oils], water, contains less than 2% of salt, enzyme-modified soybean lecithin, natural &artificial flavor, potassium sorbate and calcium disodium edta [to preserve freshness], lactic acid, vitamin a palmitate, beta-carotene color), Imitation Vanilla Extract (water, caramel color, vanillin, ethyl vanillin, and 0.1% potassium sorbate [added as a preservative]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '190',
#        'saturated_fat': '2',
#        'protein': '4',
#        'carbohydrates': '30',
#        'serving_type_code': 17},
#       {'id': 'L104660',
#        'name': 'Vegan Apple Crisp',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': True,
#        'ingredients': 'Fresh Apple, Brown Sugar (brown sugar [when produced at Chalmette or Crockett facilities] sugar, molasses [when produced at South Bay facility]), Rolled Oats, Margarine (oil blend [palm, soybean, canola, and olive oils], water, contains less than 2% of salt, enzyme-modified soybean lecithin, natural &artificial flavor, potassium sorbate and calcium disodium edta [to preserve freshness], lactic acid, vitamin a palmitate, beta-carotene color), White Sugar, Whole Wheat Flour (whole wheat flour), Lemon Juice (Sahara Burst: filtered water, lemon juice concentrate, sodium bisulfite [preservative], sodium benzoate [preservative], lemon oil) (Viaggio: water, lemon juice concentrated, sodium benzoate, sodium bisulfite, lemon oil), Corn Starch, Ground Cinnamon.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '280',
#        'saturated_fat': '2',
#        'protein': '2',
#        'carbohydrates': '57',
#        'serving_type_code': 17},
#       {'id': 'L347701',
#        'name': 'Assorted Cookies',
#        'description': 'Freshly baked assorted cookies',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': '',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '0',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '0',
#        'serving_type_code': 17}]},
#     {'station_name': 'Brick Oven',
#      'menu_items': [{'id': 'L271046',
#        'name': 'Cheese Pizza',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'White Pizza Dough (bleached enriched flour [wheat flour, malted barley flour, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], water, soybean oil, contains 2% or les of the following: yeast, sugar, salt, vital wheat gluten, dough conditioners [sodium stearoyl lactylate, ascorbic acid, enzymes, l-cysteine]) (enriched unbleached wheat flour [wheat flour, malted barley flour, niacin, iron as ferrous sulfate, thiamine mononitrate, enzyme, riboflavin, folic acid], water, yeast, soybean oil, contains less than 2% of the following: high fructose corn syrup, salt, sodium stearoyl lactylate, ascorbic acid, enzyme [MAY CONTAIN EGGS, MILK]), Shredded Mozzarella Cheese (low moisture mozzarella cheese [pasteurized milk, cheese cultures, salt, enzymes], powdered cellulose [to prevent caking], natamycin [a natural mold inhibitor]) (pasteurized part-skim milk, cheese culture, salt and enzymes, powdered cellulose added to prevent caking), Pizza Sauce (tomatoes [puree], salt, sugar, extra virgin olive oil, dehydrated basil, spices and garlic powder).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '245',
#        'saturated_fat': '4',
#        'protein': '15',
#        'carbohydrates': '34',
#        'serving_type_code': 8},
#       {'id': 'L302855',
#        'name': 'Vegan Vegetable Pizza',
#        'description': 'Vegan Vegetable Pizza',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'White Pizza Dough (bleached enriched flour [wheat flour, malted barley flour, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], water, soybean oil, contains 2% or les of the following: yeast, sugar, salt, vital wheat gluten, dough conditioners [sodium stearoyl lactylate, ascorbic acid, enzymes, l-cysteine]) (enriched unbleached wheat flour [wheat flour, malted barley flour, niacin, iron as ferrous sulfate, thiamine mononitrate, enzyme, riboflavin, folic acid], water, yeast, soybean oil, contains less than 2% of the following: high fructose corn syrup, salt, sodium stearoyl lactylate, ascorbic acid, enzyme [MAY CONTAIN EGGS, MILK]), Canned Crushed Tomatoes (Arezzio: tomatoes, tomato puree, sea salt and citric acid) (Bel-Orto: vine-ripened fresh tomatoes, tomato puree, citric acid), Sliced Black Olives (olives, water, salt, ferrous gluconate), Fresh Mushrooms, Tap Water, Baby Spinach, Sundried Tomatoes (sun-dried tomato strips, glucose, salt, sulfur dioxide [as a preservative], citric acid) (tomatoes, sulfur dioxide added for color retention and as a preservative), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Kosher Salt (salt, yellow prussiate of soda [YPS]), Garlic Powder, Ground Black Pepper, White Sugar, Oregano Leaf (dried oregano).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '245',
#        'saturated_fat': '0',
#        'protein': '9',
#        'carbohydrates': '45',
#        'serving_type_code': 8},
#       {'id': 'M22050',
#        'name': 'Boom Boom Chicken Flatbread',
#        'description': 'Whole grain flatbread with chicken, pepperoni, mozzarella, banana peppers & blend of mayo, chili sauce',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Whole Grain Flatbread (whole wheat flour, enriched unbleached wheat flour [wheat flour, malted barley flour, ascorbic acid added as a dough conditioner, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], water, soybean oil, yeast, contains less than 2% of the following: sugar, nonfat dry milk, wheat gluten, salt, leavening [sodium acid pyrophosphate, baking soda, monocalcium phosphate], sodium stearoyl lactylate, guar gum), Boneless Skinless Chicken Breast, Shredded Mozzarella Cheese (low moisture mozzarella cheese [pasteurized milk, cheese cultures, salt, enzymes], powdered cellulose [to prevent caking], natamycin [a natural mold inhibitor]) (pasteurized part-skim milk, cheese culture, salt and enzymes, powdered cellulose added to prevent caking), Mayonnaise (soybean oil, distilled vinegar, egg yolk, high fructose corn syrup, contains less than 2% of salt, water, mustard seed, calcium disodium EDTA to protect flavor), Sliced Banana Peppers (banana peppers, water, salt, acetic acid, citric acid, calcium chloride, preservatives [sodium benzoate, sodium bisulfite], capsicum oleoresin, yellow 5. contains: sulfites), Pepperoni (pork, beef, sea salt, water, contains 2% or less of spice, turbinado sugar, natural hardwood smoked sugar, cultured celery powder, acerola cherry juice powder, lime juice concentrate, oleoresin of paprika, lactic acid starter culture, rosemary extract, dextrose, natural flavors, dehydrated granulated garlic, sodium nitrite, bha, bht, citric acid), Chili Garlic Sauce (garlic, spices [including paprika, oregano, red pepper], salt, and onion), Sriracha (salted red chili pepper [red chili pepper, salt], sugar, garlic, salt, water, acetic acid, lactic acid, xanthan gum, citric acid, potassium sorbate [preservative], ascorbic acid), White Vinegar (distilled white vinegar diluted with water to 5% [50 grains] acidity), Crushed Red Peppers (dried red chili peppers), Paprika (paprika and silicon dioxide [added to make free flowing]), Onion Powder (dehydrated onion), Ground Turmeric.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '180',
#        'saturated_fat': '3',
#        'protein': '9',
#        'carbohydrates': '12',
#        'serving_type_code': 8}]},
#     {'station_name': 'Grill',
#      'menu_items': [{'id': 'L267319',
#        'name': 'Local Homestyle French Fries',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Potato Wedges (Potato, Enriched Wheat Flour [[Niacin, Reduced Iron, Thiamine, Mononitrate,  Riboflavin, Folic Acid], Malted Barley Flour], Rice Flour, Salt, Sodium Acid Pyrophosphate, Sodium Bicarbonate, Xanthan Gum, Soybean Oil and/ or Cottonseed Oil), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': True,
#        'calories': '315',
#        'saturated_fat': '4',
#        'protein': '3',
#        'carbohydrates': '30',
#        'serving_type_code': 2},
#       {'id': 'L93789',
#        'name': 'Grill Works',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': '',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '0',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '0',
#        'serving_type_code': 24}]},
#     {'station_name': 'Grill Create Your Own',
#      'menu_items': [{'id': 'M33194',
#        'name': 'Tomato',
#        'description': 'Fresh sliced tomato',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Red Tomatoes.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '80',
#        'saturated_fat': '0',
#        'protein': '4',
#        'carbohydrates': '18',
#        'serving_type_code': 3},
#       {'id': 'M14343',
#        'name': 'Sliced Red Onions',
#        'description': 'Thinly sliced red onions',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Red Onion.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '30',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '8',
#        'serving_type_code': 3},
#       {'id': 'M14856',
#        'name': 'Dill Pickle Slices',
#        'description': 'Dill pickle slices',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Canned Sliced Pickle (fresh cucumbers, water, vinegar, salt, contains less than 2% of calcium chloride, sodium benzoate [preservative], spices [contains mustard], natural flavor, polysorbate 80, dehydrated dill, dehydrated red bell peppers, turmeric extract [color]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '2',
#        'serving_type_code': 3}]},
#     {'station_name': 'Mediterranean',
#      'menu_items': [{'id': 'L333628',
#        'name': 'Grilled Chicken Breast',
#        'description': 'Sliced grilled chicken breast',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Boneless Skinless Chicken Breast, Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Ground Black Pepper, Kosher Salt (salt, yellow prussiate of soda [YPS]).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '210',
#        'saturated_fat': '2',
#        'protein': '38',
#        'carbohydrates': '0',
#        'serving_type_code': 13},
#       {'id': 'L334051',
#        'name': 'Rosemary Focaccia',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'White Pizza Dough (bleached enriched flour [wheat flour, malted barley flour, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], water, soybean oil, contains 2% or les of the following: yeast, sugar, salt, vital wheat gluten, dough conditioners [sodium stearoyl lactylate, ascorbic acid, enzymes, l-cysteine]) (enriched unbleached wheat flour [wheat flour, malted barley flour, niacin, iron as ferrous sulfate, thiamine mononitrate, enzyme, riboflavin, folic acid], water, yeast, soybean oil, contains less than 2% of the following: high fructose corn syrup, salt, sodium stearoyl lactylate, ascorbic acid, enzyme [MAY CONTAIN EGGS, MILK]), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Black Pepper, Fresh Rosemary.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '55',
#        'saturated_fat': '0',
#        'protein': '2',
#        'carbohydrates': '10',
#        'serving_type_code': 1},
#       {'id': 'L87126',
#        'name': 'Fresh Homemade Pasta',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Semolina Flour (semolina [milled from durum wheat], niacin, ferrous sulfate, thiamin mononitrate, riboflavin, folic acid), Tap Water.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '100',
#        'saturated_fat': '0',
#        'protein': '4',
#        'carbohydrates': '20',
#        'serving_type_code': 1}]},
#     {'station_name': 'International',
#      'menu_items': [{'id': 'L323879',
#        'name': 'Jerk Chicken',
#        'description': 'Baked chicken leg quarter coated with jerk seasoning',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Chicken Leg Quarters, Caribbean Jerk Seasoning (scallions, hot peppers, salt, black pepper, allspice, cane vinegar, citric acid).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '290',
#        'saturated_fat': '7',
#        'protein': '17',
#        'carbohydrates': '0',
#        'serving_type_code': 13},
#       {'id': 'L89949',
#        'name': 'Green Beans',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': True,
#        'ingredients': 'Green Beans, Margarine (oil blend [palm, soybean, canola, and olive oils], water, contains less than 2% of salt, enzyme-modified soybean lecithin, natural &artificial flavor, potassium sorbate and calcium disodium edta [to preserve freshness], lactic acid, vitamin a palmitate, beta-carotene color), Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '40',
#        'saturated_fat': '1',
#        'protein': '1',
#        'carbohydrates': '5',
#        'serving_type_code': 3},
#       {'id': 'M9636',
#        'name': 'White Rice',
#        'description': 'Slow-simmered long grain white rice',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Tap Water, White Rice (enriched parboiled long grain rice [parboiled long grain rice, vitamins and minerals [calcium [calcium carbonate], iron [iron phosphate], vitamin b1 [thiamine mononitrate], folic acid]).',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': True,
#        'calories': '120',
#        'saturated_fat': '0',
#        'protein': '2',
#        'carbohydrates': '26',
#        'serving_type_code': 1}]},
#     {'station_name': 'Home Zone',
#      'menu_items': [{'id': 'L255239',
#        'name': 'Crema',
#        'description': None,
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Sour Cream (cultured milk, cream, modified corn starch, guar gum, sodiumcitrate, carrageenan, locust bean gum), Tap Water, Kosher Salt (salt, yellow prussiate of soda [YPS]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '20',
#        'saturated_fat': '1',
#        'protein': '0',
#        'carbohydrates': '0',
#        'serving_type_code': 5}]},
#     {'station_name': 'Home Zone Create Your Own',
#      'menu_items': [{'id': 'M21742',
#        'name': 'Flour Tortilla',
#        'description': 'Soft flour tortilla',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': '12" Flour Tortilla (enriched unbleached flour [wheat flour, niacin, reduced iron, thiamine mononitrate, riboflavin, and folic acid], water, vegetable shortening [contains one or more of the following: palm oil and/or corn oil], contains 2% or less of the following: salt, aluminum-free leavening [sodium acid pyrophosphate, sodium bicarbonate, cornstarch, monocalcium phosphate], wheat protein, preservatives [calcium propoinate, sorbic acid], dough conditioner [fumaric acid, xanthan gum, mono- and diglycerides, sodium metabisulphite]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '290',
#        'saturated_fat': '4',
#        'protein': '8',
#        'carbohydrates': '48',
#        'serving_type_code': 1},
#       {'id': 'M20329',
#        'name': 'Corn Tortilla',
#        'description': 'Corn tortilla',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': '6" Corn Tortilla (yellow corn flour [whole grain yellow corn flour, trace of lime], water, wheat gluten, cultured wheat flour [cultured wheat flour, vinegar], contains 2% or less of the following: salt, soy lecithin, sodium alginate, guar gum, citric acid, wheat fiber, acacia gum [MADE IN A FACILITY THAT PROCESS SOY]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '90',
#        'saturated_fat': '0',
#        'protein': '5',
#        'carbohydrates': '16',
#        'serving_type_code': 1},
#       {'id': 'L314136',
#        'name': 'Achiote Chicken',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Chicken Thigh, Orange Juice (Orange juice concentrate, treated water, apple juice concentrate, citric acid, natural flavor, sodium benzoate [preserves freshness], potassium sorbate [preserves freshness], ascorbic acid), Fresh Jalapeno Peppers, Fresh Cilantro, Garlic Cloves, Achiote Paste (vinegar, annatto seed, spices, salt, garlic), Kosher Salt (salt, yellow prussiate of soda [YPS]), Ground Black Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '175',
#        'saturated_fat': '3',
#        'protein': '19',
#        'carbohydrates': '5',
#        'serving_type_code': 20},
#       {'id': 'L350978',
#        'name': 'Carne Asada',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Beef Inside Eye Round, Apple Cider Vinegar (apple cider vinegar reduced with water to 5% acidity), Less Sodium Soy Sauce (water, wheat, soybeans, salt, lactic acid, sodium benzoate: less than 1/10 of 1% as a preservative.), Orange Juice (Orange juice concentrate, treated water, apple juice concentrate, citric acid, natural flavor, sodium benzoate [preserves freshness], potassium sorbate [preserves freshness], ascorbic acid), Lime Juice (premium juice from gently squeezed fresh limes [mildly pasteurized for enhanced food safety]), Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Oregano Leaf (dried oregano), Garlic Cloves, Ground Black Pepper, Ground Cumin.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '155',
#        'saturated_fat': '2',
#        'protein': '24',
#        'carbohydrates': '0',
#        'serving_type_code': 20},
#       {'id': 'L337012',
#        'name': 'Cilantro-Lime Brown Rice',
#        'description': 'Brown rice with lime juice and fresh cilantro',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
# ...
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M6557',
#        'name': 'Sliced Mushrooms',
#        'description': 'Sliced fresh mushrooms',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Mushrooms.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '15',
#        'saturated_fat': '0',
#        'protein': '2',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M6570',
#        'name': 'Romaine',
#        'description': 'Chopped romaine lettuce',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Fresh Romaine.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M13531',
#        'name': 'Black Olives',
#        'description': 'Sliced pitted black olives',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Sliced Black Olives (olives, water, salt, ferrous gluconate).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '80',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '4',
#        'serving_type_code': 3},
#       {'id': 'M13985',
#        'name': 'Diced Beets',
#        'description': 'Diced beets',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Sliced Beets (beets, water, salt).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '40',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '8',
#        'serving_type_code': 3},
#       {'id': 'M14574',
#        'name': 'Sliced Green Peppers',
#        'description': 'Sliced green bell peppers',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Green Bell Pepper.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M14343',
#        'name': 'Sliced Red Onions',
#        'description': 'Thinly sliced red onions',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Red Onion.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '30',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '8',
#        'serving_type_code': 3},
#       {'id': 'M14258',
#        'name': 'Shredded Cheddar Cheese',
#        'description': 'Shredded Cheddar cheese',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Shredded Cheddar Cheese (pasteurized milk, cheese culture, salt, enzymes, annatto [if colored], potato starch and powdered cellulose added to prevent caking).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '110',
#        'saturated_fat': '5',
#        'protein': '7',
#        'carbohydrates': '0',
#        'serving_type_code': 20},
#       {'id': 'M14542',
#        'name': 'Zucchini',
#        'description': 'Sliced fresh zucchini',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Zucchini.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M14538',
#        'name': 'Sliced Yellow Squash',
#        'description': 'Sliced yellow squash',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Summer Squash.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '10',
#        'saturated_fat': '0',
#        'protein': '1',
#        'carbohydrates': '2',
#        'serving_type_code': 3},
#       {'id': 'M20121',
#        'name': 'Diced Chicken',
#        'description': 'Diced roasted fresh chicken breasts and thighs',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Chicken Thigh, Boneless Skinless Chicken Breast.',
#        'is_glutenfree': False,
#        'is_halal': True,
#        'is_sustainable': False,
#        'calories': '150',
#        'saturated_fat': '2',
#        'protein': '21',
#        'carbohydrates': '1',
#        'serving_type_code': 13},
#       {'id': 'M14257',
#        'name': 'Diced Tofu',
#        'description': 'Diced extra firm tofu',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Firm Tofu (Soga: water, soybeans, less than 2% of firming agents [calcium sulfate, magnesium chloride, and/or glucono delta lactone])(Nasoya: water, organic soybeans, less than 2% of magnesium chloride, calcium sulfate).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '70',
#        'saturated_fat': '1',
#        'protein': '7',
#        'carbohydrates': '4',
#        'serving_type_code': 11},
#       {'id': 'M14290',
#        'name': 'Feta Cheese Crumbles',
#        'description': 'Crumbled feta',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Feta Cheese (pasteurized milk and skim milk, salt, enzymes and vegetable coagulant).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '50',
#        'saturated_fat': '3',
#        'protein': '3',
#        'carbohydrates': '1',
#        'serving_type_code': 20},
#       {'id': 'M14533',
#        'name': 'Chow Mein Noodles',
#        'description': 'Crispy chow mein noodles',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Tap Water, Chow Mein Noodles (enriched wheat flour [wheat flour, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], palm oil, contains 2% or less of : salt, yeast, sugar).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '145',
#        'saturated_fat': '2',
#        'protein': '3',
#        'carbohydrates': '20',
#        'serving_type_code': 1},
#       {'id': 'M14886',
#        'name': 'Thousand Island Dressing',
#        'description': 'Creamy Thousand Island dressing',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Buttermilk Ranch (soybean oil, water, distilled vinegar, egg yolk, buttermilk solids, contains less than 2% of salt, sugar, lemon juice concentrate, garlic, * onion, * xanthan gum, sorbic acid [preservative], natural flavor, cream, spice, maltodextrin, whey, vinegar powder, buttermilk, autolyzed yeast extract, milk, sour cream powder, lactic acid, calcium disodium edta [to protect flavor], citric acid. *dried), Ketchup (tomato concentrate from red ripe tomatoes, distilled vinegar, high fructose corn syrup, corn syrup, salt, spice, onion powder, natural flavoring), Sweet Relish (cucumbers, high fructose corn syrup, cabbage, water, distilled white vinegar, salt, aluminum sulfate, xantham gum, natural flavor, dehydrated red peppers, polysorbate 80, oleoresin turmeric), Yellow Onion.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '95',
#        'saturated_fat': '1',
#        'protein': '0',
#        'carbohydrates': '4',
#        'serving_type_code': 5},
#       {'id': 'M19735',
#        'name': 'Balsamic Vinaigrette',
#        'description': 'Tangy balsamic vinaigrette dressing',
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Balsamic Vinaigrette Dressing (water, high fructose corn syrup, balsamic vinegar, red wine vinegar, vegetable oil [soybean and/or canola], olive oil, contains less than 2% of salt, garlic,* xanthan gum, spice, sodium alginate, propylene glycol alginate, calcium disodium edta [to protect flavor] *dried).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '60',
#        'saturated_fat': '1',
#        'protein': '0',
#        'carbohydrates': '5',
#        'serving_type_code': 5},
#       {'id': 'M14893',
#        'name': 'Blue Cheese Dressing',
#        'description': 'Creamy, chunky blue cheese dressing',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Chunky Blue Cheese Dressing (soybean oil, blue cheese [[cultured pasteurized milk, salt, enzymes, penicillium roqueforti], natamycin [natural mold inhibitor]], distilled vinegar, water, egg yolk, high fructose corn syrup, contains less than 2% of salt, natural flavor, monosodium glutamate, mustard flour, propylene glycol alginate, xanthan gum, onion,* garlic.* *dried).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '150',
#        'saturated_fat': '3',
#        'protein': '1',
#        'carbohydrates': '1',
#        'serving_type_code': 5},
#       {'id': 'M14894',
#        'name': 'Honey Mustard Dressing',
#        'description': 'Honey mustard salad dressing',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Honey Dijon Dressing (soybean oil, high fructose corn syrup, distilled vinegar, water, dijon mustard [distilled vinegar, water, mustard seed, salt, white wine, citric acid, tartaric acid, spice], honey, sugar, egg yolk, contains less than 2% of salt, mustard flour, xanthan gum, spice, oleoresin paprika [color], calcium disodium edta [to protect flavor], yellow 5, corn syrup, natural flavor).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '135',
#        'saturated_fat': '2',
#        'protein': '0',
#        'carbohydrates': '7',
#        'serving_type_code': 5},
#       {'id': 'M33834',
#        'name': 'Lite Italian Dressing',
#        'description': 'Lite Italian salad dressing',
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Lite Italian Dressing (water, distilled vinegar, vegetable oil [soybean and/or canola], sugar, apple cider vinegar, contains less than 2% of salt, xanthan gum, garlic*, onion*, natural flavor, maltodextrin, propylene glycol alginate, disodium inosinate and disodium guanylate, sodium benzoate and sorbic acid [preservatives], red bell pepper*, spice, autolyzed yeast extract, calcium disodium edta [to protect flavor], caramel color, yellow 5, yellow 6. *dried).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '40',
#        'saturated_fat': '1',
#        'protein': '0',
#        'carbohydrates': '2',
#        'serving_type_code': 5},
#       {'id': 'M19241',
#        'name': 'Light Ranch Dressing',
#        'description': 'Light ranch salad dressing',
#        'is_vegetarian': True,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Lite Ranch Dressing (cultured buttermilk, vegetable oil [soybean and/or canola], water, egg yolk, contains less than 2% of salt, maltodextrin, nonfat milk powder, monosodium glutamate, sugar, modified corn starch, lactic acid, potassium sorbate [preservative], nonfat milk solids, distilled vinegar, xanthan gum, onion,* cream, spice, whey, garlic,* vinegar powder, guar gum, sour cream powder, mustard flour, milk, natural flavor, dipotassium phosphate, citric acid. *dried).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '80',
#        'saturated_fat': '1',
#        'protein': '1',
#        'carbohydrates': '2',
#        'serving_type_code': 5},
#       {'id': 'L255492',
#        'name': 'Arcadia Green Mix',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Mixed Salad Greens.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '5',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '1',
#        'serving_type_code': 3},
#       {'id': 'L253792',
#        'name': 'Fresh Spinach',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Baby Spinach.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '5',
#        'saturated_fat': '0',
#        'protein': '0',
#        'carbohydrates': '1',
#        'serving_type_code': 3},
#       {'id': 'L256903',
#        'name': 'Croutons',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'Seasoned Croutons (enriched wheat flour [wheat flour, niacin, reduced iron, thiamine mononitrate, riboflavin, folic acid], canola oil, salt, sugar, rice flour, garlic powder, yeast, romano cheese [milk, culture, salt, enzymes], dehydrated parsley, onion powder, yeast extract, natural flavor, spices, BHT added to packaging to maintain freshness).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '65',
#        'saturated_fat': '0',
#        'protein': '2',
#        'carbohydrates': '11',
#        'serving_type_code': 1},
#       {'id': 'L265852',
#        'name': 'Greek Dressing',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': True,
#        'is_sargent_choice': False,
#        'ingredients': 'Vegetable Olive Oil Blend (Arrezzio: 90% soybean oil, 10% olive pomace oil) (Spagnolla: vegetable oil [may contain one or more of the following: soybean and/or canola and/or corn oil, and/or sunflower oil], olive oil, beta-carotene), Red Wine Vinegar (red wine vinegar diluted with water to 5% acidity)(red wine vinegar, potassium metabisulfite [a preservative], diluted with water to 5% acidity), Tap Water, Dijon Mustard (distilled white vinegar, mustard seed, water, salt, white wine, citric acid, tartaric acid, fruit pectin, sugar, spices), Garlic Powder, Kosher Salt (salt, yellow prussiate of soda [YPS]), Onion Powder (dehydrated onion), Ground Black Pepper, Oregano Leaf (dried oregano), Dried Basil.',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '135',
#        'saturated_fat': '2',
#        'protein': '0',
#        'carbohydrates': '1',
#        'serving_type_code': 5},
#       {'id': 'L254807',
#        'name': 'Lite Raspberry Vinaigrette',
#        'description': None,
#        'is_vegetarian': False,
#        'is_vegan': False,
#        'is_sargent_choice': False,
#        'ingredients': 'French, Lite Raspberry Vinaigrette (soybean oil, sugar, water, distilled vinegar, cider vinegar, tomato paste, honey, contains less than 2% of: salt, spice, xantham gum, onion, garlic, beet powder [color]).',
#        'is_glutenfree': False,
#        'is_halal': False,
#        'is_sustainable': False,
#        'calories': '130',
#        'saturated_fat': '2',
#        'protein': '0',
#        'carbohydrates': '7',
#        'serving_type_code': 5}]}]}}}

# %%
import requests
import datetime

base_url = "https://www.bu.edu/dining/api/locations/marciano/menu/2023-03-16/"
base_url = "https://www.bu.edu/dining/api/locations/"

menu = {}

NextDay_Date = datetime.datetime.today() + datetime.timedelta(days=1)

response.json()
